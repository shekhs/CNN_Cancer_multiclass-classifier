# %% [markdown]
# <a href="https://colab.research.google.com/github/shekhs/CNN_Cancer_multiclass-classifier/blob/main/ShushankShekhar_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# !unzip /content/gdrive/MyDrive/CNN_assignment.zip

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset

#data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
#data_dir_test = pathlib.Path('/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Test/')

data_dir_train = pathlib.Path('/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/')
data_dir_test = pathlib.Path('/content/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## test dataset 

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(len(class_names))
print(class_names)
# Out:
# 9
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
#viz using val dataset
plt.figure(figsize=(10, 10))
for images, labels in val_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
#viz using train dataset
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
#Rescaling
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

# %%
### Your code goes here
input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrapp  (None, 178, 178, 32)     896
#  er)
#
#  module_wrapper_1 (ModuleWra  (None, 176, 176, 32)     9248
#  pper)
#
#  module_wrapper_2 (ModuleWra  (None, 88, 88, 32)       0
#  pper)
#
#  module_wrapper_3 (ModuleWra  (None, 86, 86, 64)       18496
#  pper)
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  module_wrapper_4 (ModuleWra  (None, 43, 43, 64)       0
#  pper)
#
#  module_wrapper_5 (ModuleWra  (None, 41, 41, 128)      73856
#  pper)
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_6 (ModuleWra  (None, 20, 20, 128)      0
#  pper)
#
#  module_wrapper_7 (ModuleWra  (None, 51200)            0
#  pper)
#
#  module_wrapper_8 (ModuleWra  (None, 512)              26214912
#  pper)
#
#  module_wrapper_9 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_10 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_11 (ModuleWr  (None, 1)                513
#  apper)
#
#  module_wrapper_12 (ModuleWr  (None, 1)                0
#  apper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrapp  (None, 178, 178, 32)     896
#  er)
#
#  module_wrapper_1 (ModuleWra  (None, 176, 176, 32)     9248
#  pper)
#
#  module_wrapper_2 (ModuleWra  (None, 88, 88, 32)       0
#  pper)
#
#  module_wrapper_3 (ModuleWra  (None, 86, 86, 64)       18496
#  pper)
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  module_wrapper_4 (ModuleWra  (None, 43, 43, 64)       0
#  pper)
#
#  module_wrapper_5 (ModuleWra  (None, 41, 41, 128)      73856
#  pper)
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_6 (ModuleWra  (None, 20, 20, 128)      0
#  pper)
#
#  module_wrapper_7 (ModuleWra  (None, 51200)            0
#  pper)
#
#  module_wrapper_8 (ModuleWra  (None, 512)              26214912
#  pper)
#
#  module_wrapper_9 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_10 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_11 (ModuleWr  (None, 1)                513
#  apper)
#
#  module_wrapper_12 (ModuleWr  (None, 1)                0
#  apper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  batch_size = 32,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 8s 146ms/step - loss: -60945.9375 - accuracy: 0.1719 - val_loss: -63564.1602 - val_accuracy: 0.1499
# Epoch 2/20
# 56/56 [==============================] - 4s 78ms/step - loss: -763901.3125 - accuracy: 0.1724 - val_loss: -689986.9375 - val_accuracy: 0.1499
# Epoch 3/20
# 56/56 [==============================] - 4s 70ms/step - loss: -3003866.7500 - accuracy: 0.1724 - val_loss: -2715921.0000 - val_accuracy: 0.1499
# Epoch 4/20
# 56/56 [==============================] - 4s 70ms/step - loss: -7593863.0000 - accuracy: 0.1724 - val_loss: -6576708.5000 - val_accuracy: 0.1499
# Epoch 5/20
# 56/56 [==============================] - 4s 69ms/step - loss: -15065441.0000 - accuracy: 0.1724 - val_loss: -17248582.0000 - val_accuracy: 0.1499
# Epoch 6/20
# 56/56 [==============================] - 4s 69ms/step - loss: -26481426.0000 - accuracy: 0.1724 - val_loss: -25948466.0000 - val_accuracy: 0.1499
# Epoch 7/20
# 56/56 [==============================] - 4s 69ms/step - loss: -42156456.0000 - accuracy: 0.1724 - val_loss: -41561416.0000 - val_accuracy: 0.1499
# Epoch 8/20
# 56/56 [==============================] - 4s 69ms/step - loss: -63121056.0000 - accuracy: 0.1724 - val_loss: -53883568.0000 - val_accuracy: 0.1499
# Epoch 9/20
# 56/56 [==============================] - 4s 70ms/step - loss: -89103552.0000 - accuracy: 0.1724 - val_loss: -123242592.0000 - val_accuracy: 0.1499
# Epoch 10/20
# 56/56 [==============================] - 4s 69ms/step - loss: -122515656.0000 - accuracy: 0.1724 - val_loss: -133291264.0000 - val_accuracy: 0.1499
# Epoch 11/20
# 56/56 [==============================] - 4s 69ms/step - loss: -161250016.0000 - accuracy: 0.1724 - val_loss: -166152128.0000 - val_accuracy: 0.1499
# Epoch 12/20
# 56/56 [==============================] - 4s 69ms/step - loss: -206906528.0000 - accuracy: 0.1724 - val_loss: -138146464.0000 - val_accuracy: 0.1499
# Epoch 13/20
# 56/56 [==============================] - 4s 69ms/step - loss: -261169040.0000 - accuracy: 0.1724 - val_loss: -255084784.0000 - val_accuracy: 0.1499
# Epoch 14/20
# 56/56 [==============================] - 4s 70ms/step - loss: -324890048.0000 - accuracy: 0.1724 - val_loss: -215657904.0000 - val_accuracy: 0.1499
# Epoch 15/20
# 56/56 [==============================] - 4s 72ms/step - loss: -396208384.0000 - accuracy: 0.1724 - val_loss: -521767392.0000 - val_accuracy: 0.1499
# Epoch 16/20
# 56/56 [==============================] - 4s 69ms/step - loss: -479012768.0000 - accuracy: 0.1724 - val_loss: -547059072.0000 - val_accuracy: 0.1499
# Epoch 17/20
# 56/56 [==============================] - 4s 69ms/step - loss: -563720960.0000 - accuracy: 0.1724 - val_loss: -496980064.0000 - val_accuracy: 0.1499
# Epoch 18/20
# 56/56 [==============================] - 4s 69ms/step - loss: -665201856.0000 - accuracy: 0.1724 - val_loss: -779035648.0000 - val_accuracy: 0.1499
# Epoch 19/20
# 56/56 [==============================] - 4s 71ms/step - loss: -779905344.0000 - accuracy: 0.1724 - val_loss: -877619136.0000 - val_accuracy: 0.1499
# Epoch 20/20
# 56/56 [==============================] - 4s 70ms/step - loss: -900523072.0000 - accuracy: 0.1724 - val_loss: -881203008.0000 - val_accuracy: 0.1499

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 56/56 [==============================] - 1s 16ms/step - loss: -857764416.0000 - accuracy: 0.1724
# 14/14 [==============================] - 0s 16ms/step - loss: -881203008.0000 - accuracy: 0.1499
# Accuracy:  0.1724330335855484
# Validation Accuracy:  0.14988814294338226
# Loss:  -857764416.0
# Validation Loss -881203008.0

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# Thus we can clearly that model is underfit. So we need to chose right data augumentation strategy

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(data_dir_train, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(data_dir_test, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)
# Out:
# Found 890 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

#model.build(input_shape)

#model.summary()

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %%
#In order to make the optimizer converge faster and closest to the global minimum of the loss function, 
#i used an annealing method of the learning rate (LR).

#The LR is the step by which the optimizer walks through the 'loss landscape'. 
#The higher LR, the bigger are the steps and the quicker is the convergence. 
#However the sampling is very poor with an high LR and the optimizer could probably 
#fall into a local minima. 


#Set a learning rate annealer
from keras.callbacks import ReduceLROnPlateau
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
## Your code goes here, note: train your model for 20 epochs
epochs = 20
batch_size = 10
history = model.fit(train_batches,
  epochs = epochs, verbose = 1, validation_data=valid_batches , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/20
# 14/14 [==============================] - 38s 3s/step - loss: 203.4559 - accuracy: 0.4326 - val_loss: 2.1713 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 2/20
# 14/14 [==============================] - 29s 2s/step - loss: 1.1716 - accuracy: 0.4258 - val_loss: 2.1212 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/20
# 14/14 [==============================] - 30s 2s/step - loss: 1.0515 - accuracy: 0.4775 - val_loss: 2.1240 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/20
# 14/14 [==============================] - ETA: 0s - loss: 0.9980 - accuracy: 0.4899
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 [==============================] - 28s 2s/step - loss: 0.9980 - accuracy: 0.4899 - val_loss: 2.1110 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/20
# 14/14 [==============================] - 30s 2s/step - loss: 0.9862 - accuracy: 0.4562 - val_loss: 2.1125 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 6/20
# 14/14 [==============================] - 28s 2s/step - loss: 0.9494 - accuracy: 0.5079 - val_loss: 2.1016 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 7/20
# 14/14 [==============================] - ETA: 0s - loss: 0.9776 - accuracy: 0.4854
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 [==============================] - 28s 2s/step - loss: 0.9776 - accuracy: 0.4854 - val_loss: 2.0937 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 8/20
# 14/14 [==============================] - 28s 2s/step - loss: 0.9338 - accuracy: 0.5169 - val_loss: 2.0829 - val_accuracy: 0.3958 - lr: 2.5000e-04
# Epoch 9/20
# 14/14 [==============================] - 31s 2s/step - loss: 0.9068 - accuracy: 0.5247 - val_loss: 2.0375 - val_accuracy: 0.4792 - lr: 2.5000e-04
# Epoch 10/20
# 14/14 [==============================] - 32s 2s/step - loss: 0.9130 - accuracy: 0.5371 - val_loss: 2.0336 - val_accuracy: 0.4375 - lr: 2.5000e-04
# Epoch 11/20
# 14/14 [==============================] - 30s 2s/step - loss: 0.8996 - accuracy: 0.5371 - val_loss: 1.9217 - val_accuracy: 0.3125 - lr: 2.5000e-04
# Epoch 12/20
# 14/14 [==============================] - ETA: 0s - loss: 0.8814 - accuracy: 0.5427
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 [==============================] - 28s 2s/step - loss: 0.8814 - accuracy: 0.5427 - val_loss: 1.8595 - val_accuracy: 0.3542 - lr: 2.5000e-04
# Epoch 13/20
# 14/14 [==============================] - 30s 2s/step - loss: 0.8393 - accuracy: 0.5831 - val_loss: 1.7970 - val_accuracy: 0.3542 - lr: 1.2500e-04
# Epoch 14/20
# 14/14 [==============================] - 28s 2s/step - loss: 0.8380 - accuracy: 0.5798 - val_loss: 1.7483 - val_accuracy: 0.3750 - lr: 1.2500e-04
# Epoch 15/20
# 14/14 [==============================] - ETA: 0s - loss: 0.8226 - accuracy: 0.6056
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 14/14 [==============================] - 29s 2s/step - loss: 0.8226 - accuracy: 0.6056 - val_loss: 1.5750 - val_accuracy: 0.3958 - lr: 1.2500e-04
# Epoch 16/20
# 14/14 [==============================] - 28s 2s/step - loss: 0.8080 - accuracy: 0.5978 - val_loss: 1.5421 - val_accuracy: 0.3958 - lr: 6.2500e-05
# Epoch 17/20
# 14/14 [==============================] - 28s 2s/step - loss: 0.7846 - accuracy: 0.6000 - val_loss: 1.5198 - val_accuracy: 0.4167 - lr: 6.2500e-05
# Epoch 18/20
# 14/14 [==============================] - ETA: 0s - loss: 0.8069 - accuracy: 0.5910
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 14/14 [==============================] - 31s 2s/step - loss: 0.8069 - accuracy: 0.5910 - val_loss: 1.4937 - val_accuracy: 0.4583 - lr: 6.2500e-05
# Epoch 19/20
# 14/14 [==============================] - 28s 2s/step - loss: 0.7681 - accuracy: 0.6157 - val_loss: 1.6096 - val_accuracy: 0.3958 - lr: 3.1250e-05
# Epoch 20/20
# 14/14 [==============================] - 29s 2s/step - loss: 0.7583 - accuracy: 0.6236 - val_loss: 1.5451 - val_accuracy: 0.4167 - lr: 3.1250e-05

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Model performance has improved a bit, but we can still see it is overfitting.

# %%
loss, accuracy = model.evaluate(train_batches, verbose=1,)
loss_v, accuracy_v = model.evaluate(valid_batches, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 14/14 [==============================] - 24s 2s/step - loss: 1.1185 - accuracy: 0.5315
# 1/1 [==============================] - 4s 4s/step - loss: 1.5583 - accuracy: 0.3958
# Accuracy:  0.531460702419281
# Validation Accuracy:  0.3958333432674408
# Loss:  1.118546724319458
# Validation Loss 1.5583022832870483

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# Yes, Model performance has improved a significantly, but we can still see it is overfitting.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Images'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Images
# 0                    melanoma            438
# 1             vascular lesion            139
# 2        basal cell carcinoma            376
# 3                       nevus            357
# 4        seborrheic keratosis             77
# 5           actinic keratosis            114
# 6     squamous cell carcinoma            181
# 7  pigmented benign keratosis            462
# 8              dermatofibroma             95

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Images", y="Class", data=df,
            label="Class")

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples? ->seborrheic keratosis, dermatofibroma and actinic kreatosis
# #### - Which classes dominate the data in terms proportionate number of samples? -> Pigmented benign keratosis

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
#path_to_training_dataset = '/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/'
path_to_training_dataset = '/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/' 
import Augmentor
for i in class_names:
#    print(path_to_training_dataset + i)
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFB41990B10>: 100%|██████████| 500/500 [00:58<00:00,  8.57 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFBC71FC8D0>: 100%|██████████| 500/500 [00:15<00:00, 31.25 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFB6FF82E50>: 100%|██████████| 500/500 [00:16<00:00, 30.77 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7FFB419910D0>: 100%|██████████| 500/500 [01:25<00:00,  5.86 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7FFBC71FC8D0>: 100%|██████████| 500/500 [01:20<00:00,  6.21 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FFB41A7F890>: 100%|██████████| 500/500 [00:16<00:00, 31.15 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FFB41985F50>: 100%|██████████| 500/500 [00:41<00:00, 12.19 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FFAC26E3310>: 100%|██████████| 500/500 [00:15<00:00, 31.34 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFB6FF82E50>: 100%|██████████| 500/500 [00:16<00:00, 30.65 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
from glob import glob
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
#path_list

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
#lesion_list_new

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
#new_df = original_df.append(df2)
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# melanoma                      500
# vascular lesion               500
# basal cell carcinoma          500
# nevus                         500
# seborrheic keratosis          500
# actinic keratosis             500
# squamous cell carcinoma       500
# pigmented benign keratosis    500
# dermatofibroma                500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
# data_dir_train="/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
# train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#   data_dir_train,
#   seed=123,
#   validation_split = 0.2,
#   subset = 'training',
#   image_size=(img_height, img_width),
#   batch_size=batch_size)


# train dataset 
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
# val_ds = tf.keras.preprocessing.image_dataset_from_directory(
#   data_dir_train,
#   seed=123,
#   validation_split = 0.2,
#   subset = 'validation',
#   image_size=(img_height, img_width),
#   batch_size=batch_size)


# validation dataset 
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# ## your code goes here
# model = Sequential()

# # Increse the model size by adding another 32 layer
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# # Max Pool size of 2*2
# model.add(MaxPool2D(pool_size=(2, 2)))
# model.add(BatchNormalization())
# # Adding Dropout Layer
# model.add(Dropout(0.25))

# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
# model.add(MaxPool2D(pool_size=(2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.4))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPool2D(pool_size=(2, 2)))
# model.add(Dropout(0.4))

# model.add(Flatten())

# model.add(Dense(128, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(1, activation='softmax'))

# #model.summary()



#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 20, 20, 128)       0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
# ## your code goes here
# optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)


# model.compile(loss='categorical_crossentropy',
#                   optimizer=optimizer,
#                   metrics=['accuracy'])


from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %% [markdown]
# #### **Todo:**  Train your model

# %%
#epochs = 50
## Your code goes here, use 50 epochs.
# learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
#     patience=3, 
#     verbose=1, 
#     factor=0.5, 
#     min_lr=0.00001)

# batch_size = 10
# history = model.fit(train_ds,
#   epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])


# Train the model
epochs = 30
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/30
# 169/169 [==============================] - ETA: 0s - loss: 1.8117 - accuracy: 0.3166
# Epoch 1: val_accuracy improved from -inf to 0.39569, saving model to model.h5
# 169/169 [==============================] - 12s 69ms/step - loss: 1.8117 - accuracy: 0.3166 - val_loss: 1.5535 - val_accuracy: 0.3957
# Epoch 2/30
# 169/169 [==============================] - ETA: 0s - loss: 1.4967 - accuracy: 0.4336
# Epoch 2: val_accuracy improved from 0.39569 to 0.49220, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 1.4967 - accuracy: 0.4336 - val_loss: 1.3241 - val_accuracy: 0.4922
# Epoch 3/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.3839 - accuracy: 0.4800
# Epoch 3: val_accuracy improved from 0.49220 to 0.54566, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 1.3834 - accuracy: 0.4802 - val_loss: 1.2051 - val_accuracy: 0.5457
# Epoch 4/30
# 169/169 [==============================] - ETA: 0s - loss: 1.2450 - accuracy: 0.5297
# Epoch 4: val_accuracy did not improve from 0.54566
# 169/169 [==============================] - 7s 41ms/step - loss: 1.2450 - accuracy: 0.5297 - val_loss: 1.2578 - val_accuracy: 0.5367
# Epoch 5/30
# 169/169 [==============================] - ETA: 0s - loss: 1.1491 - accuracy: 0.5610
# Epoch 5: val_accuracy improved from 0.54566 to 0.58797, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 1.1491 - accuracy: 0.5610 - val_loss: 1.1014 - val_accuracy: 0.5880
# Epoch 6/30
# 169/169 [==============================] - ETA: 0s - loss: 1.0994 - accuracy: 0.5888
# Epoch 6: val_accuracy improved from 0.58797 to 0.63697, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 1.0994 - accuracy: 0.5888 - val_loss: 0.9848 - val_accuracy: 0.6370
# Epoch 7/30
# 169/169 [==============================] - ETA: 0s - loss: 1.0021 - accuracy: 0.6222
# Epoch 7: val_accuracy did not improve from 0.63697
# 169/169 [==============================] - 7s 40ms/step - loss: 1.0021 - accuracy: 0.6222 - val_loss: 0.9724 - val_accuracy: 0.6333
# Epoch 8/30
# 169/169 [==============================] - ETA: 0s - loss: 0.9447 - accuracy: 0.6467
# Epoch 8: val_accuracy improved from 0.63697 to 0.65776, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 0.9447 - accuracy: 0.6467 - val_loss: 0.9650 - val_accuracy: 0.6578
# Epoch 9/30
# 169/169 [==============================] - ETA: 0s - loss: 0.8752 - accuracy: 0.6740
# Epoch 9: val_accuracy improved from 0.65776 to 0.70082, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 0.8752 - accuracy: 0.6740 - val_loss: 0.8305 - val_accuracy: 0.7008
# Epoch 10/30
# 169/169 [==============================] - ETA: 0s - loss: 0.8090 - accuracy: 0.6923
# Epoch 10: val_accuracy did not improve from 0.70082
# 169/169 [==============================] - 7s 41ms/step - loss: 0.8090 - accuracy: 0.6923 - val_loss: 0.9293 - val_accuracy: 0.6355
# Epoch 11/30
# 169/169 [==============================] - ETA: 0s - loss: 0.7311 - accuracy: 0.7207
# Epoch 11: val_accuracy did not improve from 0.70082
# 169/169 [==============================] - 7s 41ms/step - loss: 0.7311 - accuracy: 0.7207 - val_loss: 0.8502 - val_accuracy: 0.7001
# Epoch 12/30
# 169/169 [==============================] - ETA: 0s - loss: 0.6866 - accuracy: 0.7372
# Epoch 12: val_accuracy improved from 0.70082 to 0.72977, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 0.6866 - accuracy: 0.7372 - val_loss: 0.7413 - val_accuracy: 0.7298
# Epoch 13/30
# 169/169 [==============================] - ETA: 0s - loss: 0.6625 - accuracy: 0.7522
# Epoch 13: val_accuracy improved from 0.72977 to 0.75130, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 0.6625 - accuracy: 0.7522 - val_loss: 0.6897 - val_accuracy: 0.7513
# Epoch 14/30
# 169/169 [==============================] - ETA: 0s - loss: 0.5979 - accuracy: 0.7726
# Epoch 14: val_accuracy improved from 0.75130 to 0.75872, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 0.5979 - accuracy: 0.7726 - val_loss: 0.6833 - val_accuracy: 0.7587
# Epoch 15/30
# 169/169 [==============================] - ETA: 0s - loss: 0.5617 - accuracy: 0.7825
# Epoch 15: val_accuracy improved from 0.75872 to 0.78693, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 0.5617 - accuracy: 0.7825 - val_loss: 0.6293 - val_accuracy: 0.7869
# Epoch 16/30
# 169/169 [==============================] - ETA: 0s - loss: 0.5735 - accuracy: 0.7901
# Epoch 16: val_accuracy did not improve from 0.78693
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5735 - accuracy: 0.7901 - val_loss: 0.6108 - val_accuracy: 0.7758
# Epoch 17/30
# 169/169 [==============================] - ETA: 0s - loss: 0.5277 - accuracy: 0.7954
# Epoch 17: val_accuracy did not improve from 0.78693
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5277 - accuracy: 0.7954 - val_loss: 0.6506 - val_accuracy: 0.7639
# Epoch 18/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.4798 - accuracy: 0.8121
# Epoch 18: val_accuracy did not improve from 0.78693
# 169/169 [==============================] - 7s 41ms/step - loss: 0.4791 - accuracy: 0.8123 - val_loss: 0.6320 - val_accuracy: 0.7840
# Epoch 19/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.8119
# Epoch 19: val_accuracy improved from 0.78693 to 0.79213, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 0.4735 - accuracy: 0.8119 - val_loss: 0.5914 - val_accuracy: 0.7921
# Epoch 20/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.8168
# Epoch 20: val_accuracy did not improve from 0.79213
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4724 - accuracy: 0.8168 - val_loss: 0.6649 - val_accuracy: 0.7624
# Epoch 21/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4506 - accuracy: 0.8186
# Epoch 21: val_accuracy improved from 0.79213 to 0.81811, saving model to model.h5
# 169/169 [==============================] - 7s 41ms/step - loss: 0.4506 - accuracy: 0.8186 - val_loss: 0.5377 - val_accuracy: 0.8181
# Epoch 22/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.8292
# Epoch 22: val_accuracy did not improve from 0.81811
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4375 - accuracy: 0.8292 - val_loss: 0.6488 - val_accuracy: 0.8070
# Epoch 23/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4400 - accuracy: 0.8240
# Epoch 23: val_accuracy improved from 0.81811 to 0.82331, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 0.4400 - accuracy: 0.8240 - val_loss: 0.5427 - val_accuracy: 0.8233
# Epoch 24/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4204 - accuracy: 0.8372
# Epoch 24: val_accuracy did not improve from 0.82331
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4204 - accuracy: 0.8372 - val_loss: 0.6765 - val_accuracy: 0.7892
# Epoch 25/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.8349
# Epoch 25: val_accuracy improved from 0.82331 to 0.83073, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 0.4255 - accuracy: 0.8349 - val_loss: 0.5657 - val_accuracy: 0.8307
# Epoch 26/30
# 169/169 [==============================] - ETA: 0s - loss: 0.4035 - accuracy: 0.8435
# Epoch 26: val_accuracy did not improve from 0.83073
# 169/169 [==============================] - 7s 41ms/step - loss: 0.4035 - accuracy: 0.8435 - val_loss: 0.5739 - val_accuracy: 0.8241
# Epoch 27/30
# 169/169 [==============================] - ETA: 0s - loss: 0.3515 - accuracy: 0.8572
# Epoch 27: val_accuracy did not improve from 0.83073
# 169/169 [==============================] - 7s 40ms/step - loss: 0.3515 - accuracy: 0.8572 - val_loss: 0.6078 - val_accuracy: 0.8114
# Epoch 28/30
# 169/169 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8598
# Epoch 28: val_accuracy improved from 0.83073 to 0.84187, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 0.3732 - accuracy: 0.8598 - val_loss: 0.5382 - val_accuracy: 0.8419
# Epoch 29/30
# 169/169 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.8641
# Epoch 29: val_accuracy did not improve from 0.84187
# 169/169 [==============================] - 7s 40ms/step - loss: 0.3596 - accuracy: 0.8641 - val_loss: 0.5453 - val_accuracy: 0.8404
# Epoch 30/30
# 169/169 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8741
# Epoch 30: val_accuracy improved from 0.84187 to 0.84484, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 0.3178 - accuracy: 0.8741 - val_loss: 0.5027 - val_accuracy: 0.8448

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# # Did you get rid of underfitting/overfitting? Did class rebalance help?
# ## Yes, now, the model fits better..Class rebalance  and augmentation did help in getting a better fit.

# %% [markdown]
# **Model Prediction**

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
print(np.random.randint(0,8))
# Out:
# 2

# %%
from tensorflow.keras.preprocessing.image import load_img
n = np.random.randint(0,8)
Test_image_path = os.path.join(data_dir_test, class_names[n], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[0],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[n] +'\n'+ "Predictive Class "+pred_class )
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Actual Class basal cell carcinoma
# Predictive Class basal cell carcinoma

# %% [markdown]
# # We can see, the prediction is correct.
